# %%
name = "fred"
print("his name is {var}.".format(var=name))
# using f-string
print(f"his name is {name}.")
# Out:
# his name is fred.
# his name is fred.

# %%
print(f"his name is {name!r}")
# Out:
# his name is 'fred'

# %%
library = [('author','topic','pages'),('twain','rafting',601),('feynman','physics',95),('halmilton','mythology',144)]
for book in library:
    print(f'{book[0]:{10}} {book[1]:{8}} {book[2]:.>{7}}')
# Out:
# author     topic    ..pages
# twain      rafting  ....601
# feynman    physics  .....95
# halmilton  mythology ....144

# %%
from datetime import datetime
today = datetime(year=2019, month=2, day=28)
print(f'{today:%B %d, %Y}')
# Out:
# February 28, 2019

# %%
# %%writefile test.test
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Writing test.test

# %%
my_file = open('test.test')

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'This is the second line of the file.\n']

# %%
my_file.close()

# %%
my_file = open('test.test', 'w+')

# %%
my_file.write('this is a new line')
# Out:
# 18

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['this is a new line']
