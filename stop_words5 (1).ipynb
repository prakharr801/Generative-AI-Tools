# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'with', '‘d', 'become', 'everyone', 'to', 'were', 'thence', 'which', 'and', 'mine', 'already', 'seeming', 'under', 'did', 'first', 'anyone', 'thereafter', 'by', 'than', '’ll', "'re", 'ca', 'is', 'nine', 'below', 'noone', 'fifty', 'around', 'get', 'should', '‘m', 'n’t', 'still', 'wherein', 'being', 'for', 'five', 'upon', 'used', 'you', 'those', 'hereby', 're', 'so', 'put', 'something', 'somewhere', 'because', 'hers', 'are', 'top', 'due', 'that', '’re', 'might', 'eleven', 'he', 'him', '‘ve', 'somehow', 'why', 'together', 'whose', 'i', 'them', 'through', 'indeed', 'except', 'their', 'really', 'whole', 'another', 'themselves', 'we', 'until', 'they', 'such', 'across', 'itself', 'where', 'perhaps', 'nor', 'once', 'me', 'of', 'never', 'no', 'anything', 'latter', 'in', 'well', 'before', 'anywhere', 'yet', 'sometimes', 'therein', 'without', 'its', 'whatever', 'else', 'own', 'always', 'her', 'into', 'may', 'though', 'just', 'must', 'then', "'ve", 'again', 'behind', 'call', 'move', 'who', 'neither', 'give', 'the', 'throughout', 'whenever', 'anyhow', 'often', 'elsewhere', 'do', 'about', 'on', 'thru', 'via', 'myself', 'yourself', 'amount', 'my', 'full', 'sixty', 'against', 'however', 'doing', 'other', 'hence', 'using', 'moreover', 'two', 'meanwhile', 'everywhere', 'otherwise', 'ours', 'been', 'whither', 'empty', 'would', 'herein', 'keep', 'hundred', 'but', 'wherever', 'beyond', 'thereupon', 'side', 'afterwards', 'yourselves', 'onto', 'down', 'these', '’ve', 'few', 'amongst', 'between', "n't", '’m', 'nowhere', 'thus', '‘ll', 'therefore', 'whoever', 'too', '‘s', 'up', "'s", 'besides', 'n‘t', 'this', 'enough', 'nothing', 'per', 'further', 'if', "'d", 'less', 'from', 'our', 'towards', 'various', 'toward', 'eight', 'after', 'go', 'third', 'forty', 'whence', 'himself', 'mostly', 'four', 'whereby', 'same', 'although', 'even', '’d', 'has', '‘re', 'became', 'every', 'herself', 'an', 'serious', 'as', 'others', 'seems', 'nevertheless', 'when', 'beforehand', 'us', 'during', 'ever', 'it', 'off', 'have', "'m", 'seemed', 'there', 'former', 'twelve', 'she', 'latterly', 'am', 'next', 'becomes', 'anyway', 'how', 'three', 'only', 'last', 'whereafter', 'here', 'was', 'almost', 'both', 'yours', 'twenty', 'part', 'will', 'some', 'take', 'more', 'fifteen', 'everything', 'or', 'each', 'whom', 'whether', 'be', 'now', 'while', 'since', 'name', 'none', 'regarding', 'at', 'very', 'among', 'unless', 'cannot', 'least', 'someone', 'formerly', 'any', 'your', 'becoming', 'show', 'out', 'beside', 'all', 'along', 'hereafter', 'six', 'can', 'whereas', 'back', '’s', 'ourselves', 'bottom', 'thereby', 'over', 'quite', 'one', 'above', 'could', 'please', 'namely', 'front', 'make', 'does', 'alone', 'much', 'what', 'had', 'made', 'also', 'his', 'several', 'say', 'a', "'ll", 'most', 'whereupon', 'nobody', 'hereupon', 'within', 'not', 'done', 'seem', 'either', 'ten', 'many', 'see', 'sometime', 'rather'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.vocab['roy'].is_stop
# Out:
# False

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %% [markdown]
# TO ADD A STOP WORD

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# TO REMOVE STOP WORD

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326
