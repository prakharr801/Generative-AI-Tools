# %%
s = 'i like this course.'

# %%
s.split()# it uses whit space to split the
# Out:
# ['i', 'like', 'this', 'course.']

# %%
list = []

for char in s:
    list.append(char)
print(list)
# Out:
# ['i', ' ', 'l', 'i', 'k', 'e', ' ', 't', 'h', 'i', 's', ' ', 'c', 'o', 'u', 'r', 's', 'e', '.']

# %%
text = "".join(s.split())

# %%
text
# Out:
# 'ilikethiscourse.'

# %%
list2 = []

for char in text:
    list2.append(char)
print(list2)
# Out:
# ['i', 'l', 'i', 'k', 'e', 't', 'h', 'i', 's', 'c', 'o', 'u', 'r', 's', 'e', '.']

# %%
#subword tokenization
string = "i am learning tokenization."

# %%
newString = string.split()

# %%
newString
# Out:
# ['i', 'am', 'learning', 'tokenization.']

# %%
list3 = []

for word in newString:
  if word[-3] == 'ing':
    list3.append(word.partition('ing'))
